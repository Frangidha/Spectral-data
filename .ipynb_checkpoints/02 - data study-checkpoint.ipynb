# %% [markdown]
# # **Sales price Study**

# %% [markdown]
# ## Objectives
#
# - Business Requirements: The project aims to fulfill the client's need to understand the correlation between various house attributes and sale prices.
#
# ## Inputs
# - Dataset: The project will utilize the dataset stored at outputs/datasets/collection/house_price_records.csv. This dataset contains information about house attributes and sale prices.
#
# ## Outputs
# - Create a data bisualization that explores the factors influencing house sale prices. Those important feature will be later implemented in a streamlit app.
# ## Conclusions
# - By creating the data visualization, we will gain a comprehensive understanding of the most significant factors that influence house prices. This information will assist the client in making informed decisions related to house sales, including the four inherited houses, as well as any other houses in Ames, Iowa. Important factors seem to be mainly..

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/test/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/test'

# %% [markdown]
# # Load Data

# %%
import pandas as pd
df_houseprice = pd.read_csv(f"inputs/datasets/raw/house-price-20211124T154130Z-001/house-price/house_prices_records.csv")

df_houseprice.head(3)
# Out:
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# 0       196.0          61            5            7          856         0.0
# 1         0.0           0            8            6         1262         NaN
# 2       162.0          42            5            7          920         NaN
#
#    YearBuilt  YearRemodAdd  SalePrice
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# the process of examining, summarizing, visualizing, and understanding a dataset in order to gain insights and make informed decisions for are model. we will identify pattern, relationships within the data and generate hypotheses for further analysis.

# %%
from ydata_profiling import ProfileReport
pandas_report = ProfileReport(df=df_houseprice, minimal=True)
pandas_report.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.4.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-09-29 07:40:40.092967&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### Data Variables
#
# #### 1stFlrSF
# - Description: First Floor square feet
# - Range: 334 - 4692
#
# #### 2ndFlrSF
# - Description: Second floor square feet
# - Range: 0 - 2065
#
# #### BedroomAbvGr
# - Description: Bedrooms above grade (does NOT include basement bedrooms)
# - Range: 0 - 8
#
# #### BsmtExposure
# - Description: Refers to walkout or garden level walls
# - Values:
#   - Gd: Good Exposure
#   - Av: Average Exposure
#   - Mn: Minimum Exposure
#   - No: No Exposure
#   - None: No Basement
#
# #### BsmtFinType1
# - Description: Rating of basement finished area
# - Values:
#   - GLQ: Good Living Quarters
#   - ALQ: Average Living Quarters
#   - BLQ: Below Average Living Quarters
#   - Rec: Average Rec Room
#   - LwQ: Low Quality
#   - Unf: Unfinished
#   - None: No Basement
#
# #### BsmtFinSF1
# - Description: Type 1 finished square feet
# - Range: 0 - 5644
#
# #### BsmtUnfSF
# - Description: Unfinished square feet of basement area
# - Range: 0 - 2336
#
# #### TotalBsmtSF
# - Description: Total square feet of basement area
# - Range: 0 - 6110
#
# #### GarageArea
# - Description: Size of garage in square feet
# - Range: 0 - 1418
#
# #### GarageFinish
# - Description: Interior finish of the garage
# - Values:
#   - Fin: Finished
#   - RFn: Rough Finished
#   - Unf: Unfinished
#   - None: No Garage
#
# #### GarageYrBlt
# - Description: Year garage was built
# - Range: 1900 - 2010
#
# #### GrLivArea
# - Description: Above grade (ground) living area square feet
# - Range: 334 - 5642
#
# #### KitchenQual
# - Description: Kitchen quality
# - Values:
#   - Ex: Excellent
#   - Gd: Good
#   - TA: Typical/Average
#   - Fa: Fair
#   - Po: Poor
#
# #### LotArea
# - Description: Lot size in square feet
# - Range: 1300 - 215245
#
# #### LotFrontage
# - Description: Linear feet of street connected to property
# - Range: 21 - 313
#
# #### MasVnrArea
# - D escription: Masonry veneer area in square feet
# - Range: 0 - 1600
#
# a lot of data(90%) is missing probably this feature needs to be droped
#
# #### EnclosedPorch
# - Description: Enclosed porch area in square feet
# - Range: 0 - 286
#
# #### OpenPorchSF
# - Description: Open porch area in square feet
# - Range: 0 - 547
#
# #### OverallCond
# - Description: Rates the overall condition of the house
# - Values:
#   - 10: Very Excellent
#   - 9: Excellent
#   - 8: Very Good
#   - 7: Good
#   - 6: Above Average
#   - 5: Average
#   - 4: Below Average
#   - 3: Fair
#   - 2: Poor
#   - 1: Very Poor
#
# #### OverallQual
# - Description: Rates the overall material and finish of the house
# - Values:
#   - 10: Very Excellent
#   - 9: Excellent
#   - 8: Very Good
#   - 7: Good
#   - 6: Above Average
#   - 5: Average
#   - 4: Below Average
#   - 3: Fair
#   - 2: Poor
#   - 1: Very Poor
#
# #### WoodDeckSF
# - Description: Wood deck area in square feet
# - Range: 0 - 736
#
# #### YearBuilt
# - Description: Original construction date
# - Range: 1872 - 2010
#
# #### YearRemodAdd
# - Description: Remodel date (same as construction date if no remodeling or additions)
# - Range: 1950 - 2010
#
# #### SalePrice
# - Description: Sale Price
# - Range: 34900 - 7550potential high amount of Observation
#
# - The dataset contains valuable information about various aspeDue to high percentage of missing data. these features will need to be dropped.at- the other data can be median imputed
# - the object will be ordinal encoded and frequent imputed and the dataset's characteristics.
#
# Understanding and addressing missing values is an essential part of any data analysis project to ensure the

# %% [markdown]
# ## Handling of missing values

# %% [markdown]
# isna() & sum() are used to check if the amount of counted N/A in the colums and splitting the missing varaibles in catogorical and numerical list for imputation

# %%
vars_missing_data = df_houseprice.columns[df_houseprice.isna().sum() > 0]
print("Variables with missing data:")
print(vars_missing_data) 

categorical_vars_with_missing_data = []
numerical_vars_with_missing_data = []

for var in vars_missing_data:
    if df_houseprice[var].dtype == 'object':
        categorical_vars_with_missing_data.append(var)
    else:
        numerical_vars_with_missing_data.append(var)
# Out:
# Variables with missing data:
# Index(['2ndFlrSF', 'BedroomAbvGr', 'BsmtFinType1', 'EnclosedPorch',
#        'GarageFinish', 'GarageYrBlt', 'LotFrontage', 'MasVnrArea',
#        'WoodDeckSF'],
#       dtype='object')

# %% [markdown]
# ## Imputation of Categorical Data:

# %%
print("Categorical Variables with Missing Data:")
categorical_vars_with_missing_data
# Out:
# Categorical Variables with Missing Data:
# ['BsmtFinType1', 'GarageFinish']

# %% [markdown]
# the frequent imputation method was chosen It identifies the categorical variables with missing data, calculates the mode (most frequent category)

# %%
from feature_engine.imputation import CategoricalImputer
categorical_imputer = CategoricalImputer(imputation_method='frequent', variables=categorical_vars_with_missing_data)
df_houseprice[categorical_vars_with_missing_data] = categorical_imputer.fit_transform(df_houseprice[categorical_vars_with_missing_data])

# %%
print("Information of imputed categorical variables:")
df_houseprice[categorical_vars_with_missing_data].info()
# Out:
# Information of imputed categorical variables:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BsmtFinType1  1460 non-null   object
#  1   GarageFinish  1460 non-null   object
# dtypes: object(2)
# memory usage: 22.9+ KB

# %% [markdown]
# ## Imputation of Numerical Data:

# %%
print("\nNumerical Variables with Missing Data:")
numerical_vars_with_missing_data
# Out:
# Numerical Variables with Missing Data:
# ['2ndFlrSF',
#  'BedroomAbvGr',
#  'EnclosedPorch',
#  'GarageYrBlt',
#  'LotFrontage',
#  'MasVnrArea',
#  'WoodDeckSF']

# %% [markdown]
# This will be handled later because we can run our code without imputation of the missing values.

# %% [markdown]
# # Correlation Study

# %% [markdown]
# change object into binaire numbers using onehotencoder

# %%
from feature_engine.encoding import OneHotEncoder
encoder = OneHotEncoder(variables=df_houseprice.columns[df_houseprice.dtypes=='object'].to_list(), drop_last=False)
df_ohe = encoder.fit_transform(df_houseprice)
print(df_ohe.shape)
df_ohe.head(3)
# Out:
# (1460, 40)
#    1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtFinSF1  BsmtUnfSF  EnclosedPorch  \
# 0       856     854.0           3.0         706        150            0.0
# 1      1262       0.0           3.0         978        284            NaN
# 2       920     866.0           3.0         486        434            0.0
#
#    GarageArea  GarageYrBlt  GrLivArea  LotArea  ...  BsmtFinType1_None  \
# 0         548       2003.0       1710     8450  ...                  0
# 1         460       1976.0       1262     9600  ...                  0
# 2         608       2001.0       1786    11250  ...                  0
#
#    BsmtFinType1_LwQ  GarageFinish_RFn  GarageFinish_Unf  GarageFinish_Fin  \
# 0                 0                 1                 0                 0
# 1                 0                 1                 0                 0
# 2                 0                 1                 0                 0
#
# ...

# %% [markdown]
# We use .corr() for spearman and pearson methods, and investigate the top 10 correlations
#
#
# - **Spearman Correlation**: Spearman correlation, on the other hand, is a non-parametric measure that assesses monotonic relationships between variables. It identifies whether variables tend to increase or decrease together, without assuming a constant rate of change. Spearman correlation is robust to outliers and works well with ordinal or ranked datred.

# %%
corr_spearman = df_houseprice.corr(method='spearman')['SalePrice'].sort_values(key=abs, ascending=False)[1:].head(10)
corr_spearman
# Out:
# OverallQual     0.809829
# GrLivArea       0.731310
# YearBuilt       0.652682
# GarageArea      0.649379
# TotalBsmtSF     0.602725
# GarageYrBlt     0.593788
# 1stFlrSF        0.575408
# YearRemodAdd    0.571159
# OpenPorchSF     0.477561
# LotArea         0.456461
# Name: SalePrice, dtype: float64

# %% [markdown]
# - **Pearson Correlation**: Pearson correlation is suitable for assessing linear relationships between variables. It quantifies the strength and direction of a linear relationship, ranging from -1 (perfect negative correlation) to 1 (perfect positive correlation). It is well-suited for data with linear associations.

# %%
corr_pearson = df_houseprice.corr(method='pearson')['SalePrice'].sort_values(key=abs, ascending=False)[1:].head(10)
corr_pearson
# Out:
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# BsmtFinSF1      0.386420
# Name: SalePrice, dtype: float64

# %%
top_n = 5
important_variables = set(corr_pearson[:top_n].index.to_list() + corr_spearman[:top_n].index.to_list())
print("Variables to study:")
print(important_variables)
# Out:
# Variables to study:
# {'GrLivArea', 'GarageArea', '1stFlrSF', 'YearBuilt', 'TotalBsmtSF', 'OverallQual'}

# %% [markdown]
# ## Results
# ### Strong Correlations (0.7 and Higher)
#
# - **OverallQual (0.809829)**: This attribute exhibits a very strong positive correlation with sale prices, indicating that higher overall quality is associated with higher sale prices.
# - **GrLivArea (0.731310)**: The ground living area has a strong positive correlation with sale prices, implying that larger living spaces generally result in higher sale prices.
#
# ### Moderate Correlations (Between 0.5 and 0.7)
#
# - **YearBuilt (0.652682)**: The year of construction shows a moderate positive correlation with sale prices, suggesting that newer houses tend to have higher sale prices.
# - **GarageArea (0.649379)**: Garage area demonstrates a moderate positive correlation, implying that larger garages are associated with higher sale prices.
# - **TotalBsmtSF (0.602725)**: The total basement area has a moderate positive correlation, indicating that larger basements are linked to higher sale prices.
# - **GarageYrBlt (0.593788)**: The year the garage was built also displays a moderate positive correlation with sale prices.
# - **1stFlrSF (0.575408)**: The area of the first floor has a moderate positive correlation, suggesting that larger first floors are connected to higher sale prices.
#
# ### Weak to Moderate Correlations (Between 0.5 and Lower)
#
# - **YearRemodAdd (0.571159)**: The year of remodeling demonstrates a weak to moderate positive correlation, signifying that more recent remodeling tends to be associated with higher sale prices.
# - **OpenPorchSF (0.477561)**: The open porch area exhibits a weak to moderate positive correlation, indicating that properties with larger open porches tend to have slightly higher sale prices.
# - **LotArea (0.456461)**: Lot area has a weak to moderate positive correlation with sale prices, implying that larger lots may be associated with slightly higher sale prices.

# %% [markdown]
# # EDA on selected variables

# %%
df_eda = df_houseprice.filter(list(important_variables) + ['SalePrice'])
df_eda.head(3)
# Out:
#    GrLivArea  GarageArea  1stFlrSF  YearBuilt  TotalBsmtSF  OverallQual  \
# 0       1710         548       856       2003          856            7
# 1       1262         460      1262       1976         1262            6
# 2       1786         608       920       2001          920            7
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500

# %% [markdown]
# ---

# %% [markdown]
# # Visualization

# %%
corr_matrix = df_houseprice.corr(method='pearson')
corr_with_saleprice = corr_matrix['SalePrice'].abs().sort_values(ascending=False)

# Select top correlated variables (excluding 'SalePrice' itself)
important_variables = corr_with_saleprice[1:7].index.tolist()

print("Important Variables:")
print(important_variables)
# Out:
# Important Variables:
# ['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'YearBuilt']

# %%
corr_pearson = df_houseprice.corr(method='pearson')['SalePrice'].filter(important_variables)
corr_pearson_abs = corr_pearson.abs().sort_values(ascending=False)
top_correlations = corr_pearson_abs.head(6)
top_correlations_cols = top_correlations.index.tolist()

print("Top Correlated Variables:")
print(top_correlations_cols)
# Out:
# Top Correlated Variables:
# ['OverallQual', 'GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'YearBuilt']

# %%
correlation_data = df_houseprice[top_correlations_cols + ['SalePrice']].corr(method='pearson')

print("Correlation Coefficients:")
print(correlation_data)
# Out:
# Correlation Coefficients:
#              OverallQual  GrLivArea  GarageArea  TotalBsmtSF  1stFlrSF  \
# OverallQual     1.000000   0.593007    0.562022     0.537808  0.476224
# GrLivArea       0.593007   1.000000    0.468997     0.454868  0.566024
# GarageArea      0.562022   0.468997    1.000000     0.486665  0.489782
# TotalBsmtSF     0.537808   0.454868    0.486665     1.000000  0.819530
# 1stFlrSF        0.476224   0.566024    0.489782     0.819530  1.000000
# YearBuilt       0.572323   0.199010    0.478954     0.391452  0.281986
# SalePrice       0.790982   0.708624    0.623431     0.613581  0.605852
#
#              YearBuilt  SalePrice
# OverallQual   0.572323   0.790982
# GrLivArea     0.199010   0.708624
# GarageArea    0.478954   0.623431
# TotalBsmtSF   0.391452   0.613581
# 1stFlrSF      0.281986   0.605852
# YearBuilt     1.000000   0.522897
# SalePrice     0.522897   1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Correlation Matrix

# %%
def plot_heatmap(data):
    
    matrix = np.triu(correlation_data)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(data, annot=True, cmap='coolwarm', square=True, mask=matrix)
    plt.title("Correlation Matrix", fontsize=20)
    plt.show()

plot_heatmap(correlation_data)

# %%
def plot_pairplot(data, variables):
    sns.pairplot(data[variables + [target_var]])
    plt.show()
    
target_var = 'SalePrice'
plot_pairplot(df_houseprice, important_variables)

# %% [markdown]
# ---

# %% [markdown]
# # Conclusions

# %% [markdown]
# ## Hypotheses for House Sale Prices
#
# These hypotheses are based on the observed correlations and provide valuable insights into the key factors influencing house sale prices during the data visualization.
#
#
# ### Hypothesis 1: Overall Quality
#
# - **Hypothesis**: The overall quality of a house significantly impacts its selling price.
# - **Explanation**: The data reveals a particularly strong correlation between the overall quality of a house and its sale price. We hypothesize that houses of higher quality, as rated by this attribute, typically command higher selling prices.
#
# ### Hypothesis 2: Above Ground Living Area
#
# - **Hypothesis**: The above-ground living area is a crucial factor in determining the selling price of a house.
# - **Explanation**: The data indicates a robust positive correlation between above-ground living area and sale price. We hypothesize that houses with larger living spaces in this category tend to have higher selling prices.
#
# ### Hypothesis 3: Year Built
#
# - **Hypothesis**: The year a house was built has a moderate impact on its selling price.
# - **Explanation**: The correlation analysis shows a moderate positive correlation between the year a house was built and its sale price. We hypothesize that newer houses generally command higher prices, albeit to a lesser extent compared to other factors.
#
# ### Hypothesis 4: Garage Area
#
# - **Hypothesis**: The size of the garage plays a significant role in determining the selling price of a house.
# - **Explanation**: The data reveals a strong positive correlation between garage area and sale price. We hypothesize that houses with larger garages tend to have higl estate market..rice.
